# %%
#학습자 배경영역
import pandas as pd
import matplotlib.pyplot as plt1
import seaborn as sns1

#학습자배경정보 파일 읽어들이기
df1= pd.read_csv('./dataset/studyset_2013_2017_stdinfo_notitle.csv', names = ['dept', 'grade', 'stdsex', 'addr', 'nation', 'gradu', 'job', 'age', 'scholar','passYn'],index_col=1, engine='python')
print(df1.head())

sns1.pairplot(df1, hue='dept');
plt1.show()

plt1.figure(figsize=(8,8))
sns2.heatmap(df1.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat, linecolor='green', annot=True)
# Out:
#        dept  stdsex  addr  nation  gradu  job   age  scholar  passYn
# grade
# 4      9155       1     2       1      0    0  30.0        0       1
# 4      9155       1     1       1      0    0  30.0        0       1
# 4      9135       1     1       1      0    2  30.0        0       1
# 4      9121       1     1       1     15   24  30.0        1       1
# 2      9114       1     2       1     13    0  30.0        0       0
# C:\Users\hiranMain\Anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# C:\Users\hiranMain\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
#학습활동 영역
import pandas as pd
import matplotlib.pyplot as plt2
import seaborn as sns2

df2= pd.read_csv('./dataset/studyset_2013_2017_ativity_no2.csv', names = ['loginCnt','ratestudy','bbscnt','replyCnt','counselcnt','PassYn'],index_col=1, engine='python')
print(df2.head())

sns2.pairplot(df2, hue='loginCnt');
plt2.show()

plt2.figure(figsize=(8,8))
sns2.heatmap(df2.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat, linecolor='green', annot=True)
# Out:
#            loginCnt  bbscnt  replyCnt  counselcnt  PassYn
# ratestudy
# 100             180       2         0           2       1
# 87               10       0         0           6       1
# 100              20       0         0          10       1
# 100              50       1         0           3       1
# 97              100       6         0           4       0

# %%
#교육영역 관련 영역
import pandas as pd
import matplotlib.pyplot as plt3
import seaborn as sns3

df3= pd.read_csv('./dataset/studyset_2013_2017_subject_no.csv', names = ['profbbscnt','attendcnt','totsteptime','reportcnt','testcnt','PassYn'],index_col=1, engine='python')
print(df3.head())
sns3.pairplot(df3, hue='profbbscnt');
plt3.show()
# Out:
#     profbbscnt  attendcnt  totsteptime  reportcnt  testcnt  PassYn
# 18          80         78         2574         14        4       1
# 3           20         39          507          2        0       1
# 8           90         39         1157          5        2       1
# 15         280         65         2301          6        8       1
# 18         670        163         2761          8        6       0

# %%
plt3.figure(figsize=(12,12))
sns3.heatmap(df3.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat, linecolor='green', annot=True)

# %%
#학습환경 &학습결과 영역
import pandas as pd
import matplotlib.pyplot as plt4
import seaborn as sns4

df4= pd.read_csv('./dataset/studyset_2013_2017_env_no.csv', names = ["mobile","nati","result_fgradecnt","tot_ave","tot_tak","tot_pass","passYn"],index_col=1, engine='python')
print(df4.head())

sns4.pairplot(df4, hue='mobile');
plt4.show()


plt4.figure(figsize=(8,8))
sns4.heatmap(df4.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat, linecolor='green', annot=True)
# Out:
#       mobile  result_fgradecnt  tot_ave  tot_tak  tot_pass  passYn
# nati
# 1         11                 0     4.00       18         4       1
# 1          0                 3     0.00        0         4       1
# 1          0                 3     1.56        5         4       1
# 1          3                 0     3.80       15         4       1
# 1          0                 0     4.08       18         4       0
